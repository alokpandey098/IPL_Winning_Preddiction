# %%
# Importing required libraries

import pandas as pd
import numpy as np

# %% [markdown]
# Data Ingestion Step

# %%
df_match = pd.read_csv('data\matches.csv')

# %%
df_deliveries = pd.read_csv('data\deliveries.csv')

# %%
df_match.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df_deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df_deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
df_match.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
df_deliveries.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df_match.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
df_deliveries.shape
# Out:
# (179078, 21)

# %%
df_match.shape
# Out:
# (756, 18)

# %%
df_deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
total_score=df_deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score[total_score['inning'] == 1]
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
total_score=total_score[total_score['inning'] == 1]

# %%
match_dataset = df_match.merge(total_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_dataset.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match_dataset['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
playable_teams=[
    'Mumbai Indians',
    'Chennai Super Kings',
    'Kolkata Knight Riders',
    'Royal Challengers Bangalore',
    'Rajasthan Royals',
    'Kings XI Punjab',
    'Delhi Capitals',
    'Sunrisers Hyderabad',


]

# %%
match_dataset['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
#                   ...
# 751          Kolkata Knight Riders
# 752            Chennai Super Kings
# 753            Sunrisers Hyderabad
# 754                 Delhi Capitals
# 755                 Mumbai Indians
# Name: team1, Length: 756, dtype: object

# %%
match_dataset['team1'] = match_dataset['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_dataset['team2'] = match_dataset['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_dataset['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
#                   ...
# 751          Kolkata Knight Riders
# 752            Chennai Super Kings
# 753            Sunrisers Hyderabad
# 754                 Delhi Capitals
# 755                 Mumbai Indians
# Name: team1, Length: 756, dtype: object

# %%
match_dataset['team1'] = match_dataset['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_dataset['team2'] = match_dataset['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match_dataset[match_dataset['team1'].isin(playable_teams)]
match_dataset[match_dataset['team2'].isin(playable_teams)]
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 5        6  IPL-2017      Hyderabad  09-04-2017                Gujarat Lions
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_dataset = match_dataset[match_dataset['team1'].isin(playable_teams)]
match_dataset = match_dataset[match_dataset['team2'].isin(playable_teams)]

# %%
match_dataset['dl_applied'].value_counts()
# Out:
# dl_applied
# 0    626
# 1     15
# Name: count, dtype: int64

# %% [markdown]
# * There was 15 matches in which DL method applied

# %%
match_dataset[match_dataset['dl_applied']==0]
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 7        8  IPL-2017         Indore  10-04-2017  Royal Challengers Bangalore
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_dataset = match_dataset[match_dataset['dl_applied']==0]

# %%
match_dataset[['match_id','city','winner','total_runs']]
# Out:
#      match_id           city                       winner  total_runs
# 0           1      Hyderabad          Sunrisers Hyderabad         207
# 4           5      Bangalore  Royal Challengers Bangalore         157
# 6           7         Mumbai               Mumbai Indians         178
# 7           8         Indore              Kings XI Punjab         148
# 9          10         Mumbai               Mumbai Indians         158
# ..        ...            ...                          ...         ...
# 751     11347         Mumbai               Mumbai Indians         143
# 752     11412        Chennai               Mumbai Indians         136
# 753     11413  Visakhapatnam               Delhi Capitals         171
# 754     11414  Visakhapatnam          Chennai Super Kings         155
# 755     11415      Hyderabad               Mumbai Indians         152
#
# [626 rows x 4 columns]

# %%
match_dataset = match_dataset[['match_id','city','winner','total_runs']]

# %%
delivery_dataset = match_dataset.merge(df_deliveries,on='match_id')

# %%
delivery_dataset
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
delivery_dataset[delivery_dataset['inning']==2]
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 149573     11415  Hyderabad       Mumbai Indians           152       2
# 149574     11415  Hyderabad       Mumbai Indians           152       2
# 149575     11415  Hyderabad       Mumbai Indians           152       2
# 149576     11415  Hyderabad       Mumbai Indians           152       2
# 149577     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
delivery_dataset = delivery_dataset[delivery_dataset['inning']==2]

# %%
delivery_dataset['total_runs_y'].dtype
# Out:
# dtype('int64')

# %%
delivery_dataset['total_runs_y'] = delivery_dataset['total_runs_y'].astype(int)
delivery_dataset['current_score'] = delivery_dataset.groupby('match_id')['total_runs_y'].cumsum()
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\3342754160.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['total_runs_y'] = delivery_dataset['total_runs_y'].astype(int)
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\3342754160.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['current_score'] = delivery_dataset.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_dataset.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... legbye_runs noball_runs  penalty_runs  batsman_runs  \
# 125       CH Gayle  ...           0           0             0             1
# ...

# %%
delivery_dataset['Runs left'] = delivery_dataset['total_runs_x'] - delivery_dataset['current_score']+1
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\3194355503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['Runs left'] = delivery_dataset['total_runs_x'] - delivery_dataset['current_score']+1

# %%
delivery_dataset['Balls left'] = 126 - (delivery_dataset['over']*6 + delivery_dataset['ball'])
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\195424215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['Balls left'] = 126 - (delivery_dataset['over']*6 + delivery_dataset['ball'])

# %%
delivery_dataset.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# ...

# %%
delivery_dataset['player_dismissed'] = delivery_dataset['player_dismissed'].fillna("0")
delivery_dataset['player_dismissed'] = delivery_dataset['player_dismissed'].apply(lambda x:x if x == "0" else "1")
delivery_dataset['player_dismissed'] = delivery_dataset['player_dismissed'].astype('int')
wickets = delivery_dataset.groupby('match_id')['player_dismissed'].cumsum().values
delivery_dataset['wickets'] = 10 - wickets
delivery_dataset.head()
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\599021665.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['player_dismissed'] = delivery_dataset['player_dismissed'].fillna("0")
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\599021665.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['player_dismissed'] = delivery_dataset['player_dismissed'].apply(lambda x:x if x == "0" else "1")
# ...

# %%
delivery_dataset.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# 125       CH Gayle  ...            1          0             1
# ...

# %%
delivery_dataset['CRR'] = (delivery_dataset['current_score']*6)/(120 - delivery_dataset['Balls left'])
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\450482236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['CRR'] = (delivery_dataset['current_score']*6)/(120 - delivery_dataset['Balls left'])

# %%
delivery_dataset['RRR'] = (delivery_dataset['Runs left']*6)/delivery_dataset['Balls left']
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\1941404829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['RRR'] = (delivery_dataset['Runs left']*6)/delivery_dataset['Balls left']

# %%
delivery_dataset.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... total_runs_y player_dismissed  dismissal_kind  \
# 125       CH Gayle  ...            1                0             NaN
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_dataset['result'] = delivery_dataset.apply(result,axis=1)
# Out:
# C:\Users\Alokp\AppData\Local\Temp\ipykernel_13684\2393853288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delivery_dataset['result'] = delivery_dataset.apply(result,axis=1)

# %%
final_dataset = delivery_dataset[['batting_team','bowling_team','city','Runs left','Balls left','wickets','total_runs_x','CRR','RRR','result']]

# %%
final_dataset.head()
# Out:
#                     batting_team         bowling_team       city  Runs left  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        207
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        205
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        201
#
#      Balls left  wickets  total_runs_x  CRR        RRR  result
# 125         119       10           207  6.0  10.436975       0
# 126         118       10           207  3.0  10.525424       0
# 127         117       10           207  2.0  10.615385       0
# 128         116       10           207  4.5  10.603448       0
# 129         115       10           207  8.4  10.486957       0

# %%
final_dataset = final_dataset.sample(final_dataset.shape[0])
final_dataset.sample()
# Out:
#                 batting_team     bowling_team     city  Runs left  Balls left  \
# 94450  Kolkata Knight Riders  Kings XI Punjab  Cuttack         48          47
#
#        wickets  total_runs_x       CRR      RRR  result
# 94450        9           149  8.383562  6.12766       1

# %%
final_dataset.dropna(inplace=True)

# %%
final_dataset = final_dataset[final_dataset['Balls left'] != 0]

# %%
X = final_dataset.iloc[:,:-1]
y = final_dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71342 entries, 38858 to 76600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   batting_team  71342 non-null  object
#  1   bowling_team  71342 non-null  object
#  2   city          71342 non-null  object
#  3   Runs left     71342 non-null  int64
#  4   Balls left    71342 non-null  int64
#  5   wickets       71342 non-null  int32
#  6   total_runs_x  71342 non-null  int64
#  7   CRR           71342 non-null  float64
#  8   RRR           71342 non-null  float64
#  9   result        71342 non-null  int64
# dtypes: float64(2), int32(1), int64(4), object(3)
# memory usage: 5.7+ MB

# %%
final_dataset.head()
# Out:
#                        batting_team      bowling_team       city  Runs left  \
# 38858   Royal Challengers Bangalore  Delhi Daredevils  Bangalore         97
# 95944         Kolkata Knight Riders    Mumbai Indians    Cuttack          4
# 75919   Royal Challengers Bangalore  Delhi Daredevils  Bangalore         24
# 141000               Mumbai Indians   Kings XI Punjab     Mumbai        150
# 63494               Kings XI Punjab    Mumbai Indians     Mumbai         81
#
#         Balls left  wickets  total_runs_x       CRR        RRR  result
# 38858           52        7           183  7.676471  11.192308       0
# 95944           10        7           141  7.527273   2.400000       1
# 75919           26        8           152  8.234043   5.538462       1
# 141000          76        9           204  7.500000  11.842105       1
# 63494           51        8           163  7.217391   9.529412       1

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Grid searchcv

# %%
model=LogisticRegression()
penalty=['l1', 'l2', 'elasticnet']
c_values=[100,10,1.0,0.1,0.01]
solver=['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']

# %%
params=dict(penalty=penalty,C=c_values,solver=solver)

# %%
from sklearn.model_selection import StratifiedKFold
cv=StratifiedKFold()

# %%
from sklearn.model_selection import GridSearchCV

grid=GridSearchCV(estimator=model,param_grid=params,scoring='accuracy',cv=cv,n_jobs=-1)

# %%
grid
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [100, 10, 1.0, 0.1, 0.01],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Task 3 IPL win prediction\IPL_Model.ipynb Cell 67 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Task%203%20IPL%20win%20prediction/IPL_Model.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> grid.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='newton-cg',C=100))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# c:\Task 3 IPL win prediction\venv\lib\site-packages\sklearn\preprocessing\_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(C=100, solver='newton-cg'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8040507393650571

# %%
import pickle
pickle.dump(pipe,open('model.pkl','wb'))

# %%
final_dataset.head()
# Out:
#                        batting_team      bowling_team       city  Runs left  \
# 38858   Royal Challengers Bangalore  Delhi Daredevils  Bangalore         97
# 95944         Kolkata Knight Riders    Mumbai Indians    Cuttack          4
# 75919   Royal Challengers Bangalore  Delhi Daredevils  Bangalore         24
# 141000               Mumbai Indians   Kings XI Punjab     Mumbai        150
# 63494               Kings XI Punjab    Mumbai Indians     Mumbai         81
#
#         Balls left  wickets  total_runs_x       CRR        RRR  result
# 38858           52        7           183  7.676471  11.192308       0
# 95944           10        7           141  7.527273   2.400000       1
# 75919           26        8           152  8.234043   5.538462       1
# 141000          76        9           204  7.500000  11.842105       1
# 63494           51        8           163  7.217391   9.529412       1
